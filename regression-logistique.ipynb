# %%
import matplotlib.pyplot as pyplot
from numpy import exp
from numpy import log

# %%
def sigmoid(z):
    pass

# %%
# afficher dans un graphique les résultats de la fonction sigmoid

# %%
pyplot.plot(range(1,100), [-log(x) for x in range(1,100)])

# %%
pyplot.plot(range(1,100), [-log(101 - x) for x in range(1,100)])

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification
from sklearn.linear_model import SGDClassifier
# Génération de données aléatoires: 100 exemples, 2 classes, 2 features x0 et x1
x, y = make_classification(n_samples=100,n_features=2, n_redundant=0, n_informative=1,n_clusters_per_class=1)
# Visualisation des données
# Out:
# (100, 2)

# %%
# Génération d'un modele en utilisant la fonction cout 'log' pour Logistic Regression sur la classe SGDClassifier

# Entrainer le modèle

# Afficher le score (plus c'est proche de 1 mieux c'est)
# Out:
# score: 1.0
